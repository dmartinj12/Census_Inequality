# %%
# Import our dependencies
# Conflict
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pandas as pd
from pathlib import Path

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def preprocessFile(filename = Path('../Data/AdultCensusUpdated.csv')):
    
    print(f'Preprocessing file {filename}')
    dtype_mapper = {'age': 'int64',
                    'workclass': 'string',
                    'fnlwgt': 'int64',
                    'education': 'string',
                    'education.num': 'int64',
                    'marital.status': 'string',
                    'occupation': 'string',
                    'relationship': 'string',
                    'race': 'string',
                    'sex': 'string',
                    'capital.gain': 'int64',
                    'capital.loss': 'int64',
                    'hours.per.week': 'int64',
                    'native.country': 'string',
                    'income': 'string',
                    'State': 'string'}
    df = pd.read_csv(filename, dtype=dtype_mapper, na_values='?')    
    df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
       'marital_status', 'occupation', 'relationship', 'race', 'sex',
       'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
       'income', 'state']
    df = df.drop(['fnlwgt',
                  'education', 
                #   'state',
                  'capital_gain', 
                  'capital_loss',
                  'native_country'], axis=1)
    df = df.dropna()
    return df

census_df = preprocessFile()
census_df.sample(10)
# Out:
# Preprocessing file ..\Data\AdultCensusUpdated.csv
#        age  workclass  education_num      marital_status       occupation  \
# 8833    39  Local-gov              9  Married-civ-spouse  Protective-serv
# 23227   27    Private              9       Never-married            Sales
# 22433   52    Private              9  Married-civ-spouse     Craft-repair
# 4517    17    Private              3       Never-married    Other-service
# 26023   30    Private              5  Married-civ-spouse     Craft-repair
# 13458   35    Private             15       Never-married   Prof-specialty
# 2810    61  Local-gov             14  Married-civ-spouse  Exec-managerial
# 2538    38  State-gov             16  Married-civ-spouse   Prof-specialty
# 23254   19    Private             10       Never-married  Farming-fishing
# 7628    20    Private              9       Never-married            Sales
#
#          relationship                race     sex  hours_per_week income  \
# 8833          Husband               White    Male              56  <=50K
# 23227       Own-child               Black    Male              60  <=50K
# 22433         Husband               White    Male              40  <=50K
# 4517   Other-relative               White    Male              48  <=50K
# 26023         Husband               Other    Male              40  <=50K
# 13458   Not-in-family  Asian-Pac-Islander    Male              40   >50K
# 2810          Husband               White    Male              60   >50K
# 2538             Wife               White  Female              40   >50K
# 23254   Not-in-family               White  Female              15  <=50K
# 7628        Own-child               White  Female              20  <=50K
#
#                 state
# 8833   South Carolina
# 23227         Indiana
# 22433         Arizona
# 4517        Minnesota
# 26023        Oklahoma
# 13458       Tennessee
# 2810     Rhode Island
# 2538          Indiana
# 23254   Massachusetts
# 7628    West Virginia

# %%
census_df.shape
# Out:
# (30718, 11)

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30718 entries, 1 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30718 non-null  int64
#  1   workclass       30718 non-null  string
#  2   education_num   30718 non-null  int64
#  3   marital_status  30718 non-null  string
#  4   occupation      30718 non-null  string
#  5   relationship    30718 non-null  string
#  6   race            30718 non-null  string
#  7   sex             30718 non-null  string
#  8   hours_per_week  30718 non-null  int64
#  9   income          30718 non-null  string
#  10  state           30718 non-null  string
# dtypes: int64(3), string(8)
# memory usage: 2.8 MB

# %%
for col in census_df:
    print('-' * 20)
    print(census_df[col].value_counts())
    print('-' * 20)
# Out:
# --------------------
# age
# 36    875
# 31    869
# 34    860
# 37    849
# 33    849
#      ...
# 82      7
# 83      5
# 88      3
# 85      3
# 86      1
# Name: count, Length: 72, dtype: int64
# --------------------
# --------------------
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Name: count, dtype: Int64
# --------------------
# --------------------
# education_num
# 9     9968
# 10    6775
# 13    5182
# 14    1675
# 11    1321
# 7     1056
# 12    1020
# 6      831
# 4      573
# 15     558
# 5      463
# 16     398
# 8      393
# 3      303
# 2      156
# 1       46
# Name: count, dtype: int64
# --------------------
# --------------------
# marital_status
# Married-civ-spouse       14339
# Never-married             9912
# Divorced                  4258
# Separated                  959
# Widowed                    840
# Married-spouse-absent      389
# Married-AF-spouse           21
# Name: count, dtype: Int64
# --------------------
# --------------------
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: Int64
# --------------------
# --------------------
# relationship
# Husband           12704
# Not-in-family      7865
# Own-child          4525
# Unmarried          3271
# Wife               1435
# Other-relative      918
# Name: count, dtype: Int64
# --------------------
# --------------------
# race
# White                 26301
# Black                  2909
# Asian-Pac-Islander      974
# Amer-Indian-Eskimo      286
# Other                   248
# Name: count, dtype: Int64
# --------------------
# --------------------
# sex
# Male      20788
# Female     9930
# Name: count, dtype: Int64
# --------------------
# --------------------
# hours_per_week
# 40    14525
# 50     2763
# 45     1791
# 60     1441
# 35     1203
#       ...
# 94        1
# 82        1
# 92        1
# 87        1
# 74        1
# Name: count, Length: 94, dtype: int64
# --------------------
# --------------------
# income
# <=50K    23068
# >50K      7650
# Name: count, dtype: Int64
# --------------------
# --------------------
# state
# South Carolina    700
# Texas             675
# Colorado          670
# New Hampshire     664
# Oklahoma          662
# South Dakota      653
# Delaware          652
# Louisiana         649
# North Dakota      643
# Alabama           643
# Minnesota         636
# Iowa              633
# Alaska            633
# New York          629
# Florida           626
# West Virginia     625
# North Carolina    624
# Georgia           624
# Montana           621
# Oregon            620
# Kentucky          618
# California        616
# Illinois          614
# Michigan          612
# Nevada            610
# Nebraska          610
# Arkansas          606
# Tennessee         605
# Washington        605
# Idaho             604
# Missouri          602
# Rhode Island      601
# Kansas            601
# Mississippi       601
# Utah              597
# New Mexico        594
# Virginia          593
# Pennsylvania      592
# Ohio              592
# Vermont           590
# Maryland          587
# Wisconsin         587
# Indiana           587
# New Jersey        586
# Massachusetts     583
# Wyoming           582
# Maine             581
# Hawaii            568
# Arizona           557
# Connecticut       555
# Name: count, dtype: Int64
# --------------------

# %% [markdown]
# ### Separate the features X from the target y

# %%
y = census_df.income

X = census_df.copy()
X.drop('income', axis=1, inplace=True)

# %%
X.head()
# Out:
#    age workclass  education_num marital_status         occupation  \
# 1   82   Private              9        Widowed    Exec-managerial
# 3   54   Private              4       Divorced  Machine-op-inspct
# 4   41   Private             10      Separated     Prof-specialty
# 5   34   Private              9       Divorced      Other-service
# 6   38   Private              6      Separated       Adm-clerical
#
#     relationship   race     sex  hours_per_week       state
# 1  Not-in-family  White  Female              18    Maryland
# 3      Unmarried  White  Female              40       Idaho
# 4      Own-child  White  Female              40     Florida
# 5      Unmarried  White  Female              45     Florida
# 6      Unmarried  White    Male              40  California

# %%
# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply Label Encoding to each non-numeric column
for col in X.select_dtypes(include=["string"]).columns:
    X[col] = label_encoder.fit_transform(X[col])

X.head()
# Out:
#    age  workclass  education_num  marital_status  occupation  relationship  \
# 1   82          2              9               6           3             1
# 3   54          2              4               0           6             4
# 4   41          2             10               5           9             3
# 5   34          2              9               0           7             4
# 6   38          2              6               5           0             4
#
#    race  sex  hours_per_week  state
# 1     4    0              18     19
# 3     4    0              40     11
# 4     4    0              40      8
# 5     4    0              45      8
# 6     4    1              40      4

# %% [markdown]
# ### Separate the data into training and testing subsets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Scale the data using `StandardScaler`

# %%
# Instantiate a StandardScaler instance
scaler = StandardScaler()

# Fit the training data to the standard scaler
X_scaler =scaler.fit(X_train)

# Transform the training data using the scaler
X_train_scaled = X_scaler.transform(X_train)

# Transform the testing data using the scaler
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=700, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)
print(predictions)
# Out:
# ['<=50K' '>50K' '>50K' ... '<=50K' '<=50K' '<=50K']

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         5188          564
# Actual 1          805         1123
# Accuracy Score : 0.8217447916666667
# Classification Report
#               precision    recall  f1-score   support
#
#        <=50K       0.87      0.90      0.88      5752
#         >50K       0.67      0.58      0.62      1928
#
#     accuracy                           0.82      7680
#    macro avg       0.77      0.74      0.75      7680
# weighted avg       0.82      0.82      0.82      7680

# %% [markdown]
# ### Analyze The important features

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.1958102822628419, 'age'),
#  (0.18660355682044058, 'state'),
#  (0.15009738858981922, 'education_num'),
#  (0.11917805820667864, 'relationship'),
#  (0.10278173095945964, 'hours_per_week'),
#  (0.08868318749532667, 'occupation'),
#  (0.07511266932200276, 'marital_status'),
#  (0.04890025273821884, 'workclass'),
#  (0.019306185107151888, 'race'),
#  (0.013526688498059899, 'sex')]

# %% [markdown]
# ### Graph Features by Importance

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>

# %% [markdown]
# ### Add test results to original dataframe

# %%
# Adding Results to X_test dataframe
# Adding to X-Test becasue it has the same index as original dataframe
model_name=[]
for value in predictions:
    model_name.append('RandomForest')

X_test['Results'] = predictions
X_test['Model'] = model_name

# Drop unnecessary columns
X_test = X_test.drop(columns = ['age', 'workclass', 'education_num', 'marital_status', 'occupation', 
            'relationship', 'race', 'sex', 'hours_per_week', 'state'])

X_test.head()
# Out:
#       Results         Model
# 3314    <=50K  RandomForest
# 19677    >50K  RandomForest
# 29448    >50K  RandomForest
# 3581    <=50K  RandomForest
# 25490   <=50K  RandomForest

# %%
# Copy original reprocess dataset
census_copy_df = census_df.copy()

#Join result data to original
census_copy_df = census_copy_df.join(X_test)
census_copy_df = census_copy_df.dropna(axis=0, how='any')
census_copy_df.head(20)
# Out:
#     age         workclass  education_num         marital_status  \
# 1    82           Private              9                Widowed
# 4    41           Private             10              Separated
# 13   32           Private             14              Separated
# 16   45           Private              7               Divorced
# 22   61           Private              9               Divorced
# 26   33           Private              2     Married-civ-spouse
# 27   49           Private              3     Married-civ-spouse
# 28   37      Self-emp-inc              6          Never-married
# 30   23           Private             10              Separated
# 36   53           Private              9          Never-married
# 37   51           Private             15          Never-married
# 38   37  Self-emp-not-inc             16          Never-married
# 40   44           Private             13               Divorced
# 41   43           Private             14               Divorced
# 42   51           Private             10               Divorced
# 45   48           Private             13  Married-spouse-absent
# 51   50           Private              9                Widowed
# 52   51         State-gov             11               Divorced
# 53   42           Private             10          Never-married
# 63   51  Self-emp-not-inc             13     Married-civ-spouse
#
#           occupation   relationship                race     sex  \
# 1    Exec-managerial  Not-in-family               White  Female
# 4     Prof-specialty      Own-child               White  Female
# 13   Exec-managerial  Not-in-family               White    Male
# 16  Transport-moving  Not-in-family               White    Male
# 22             Sales      Unmarried               White  Female
# 26      Craft-repair  Not-in-family               White    Male
# 27     Other-service        Husband               White    Male
# 28  Transport-moving  Not-in-family               White    Male
# 30     Other-service  Not-in-family               White    Male
# 36             Sales  Not-in-family               White    Male
# 37    Prof-specialty  Not-in-family               White  Female
# 38    Prof-specialty  Not-in-family               White  Female
# 40   Exec-managerial      Unmarried               White    Male
# 41   Exec-managerial      Unmarried               White  Female
# 42      Adm-clerical      Unmarried               White  Female
# 45             Sales      Unmarried               White  Female
# 51             Sales  Not-in-family               White  Female
# 52      Tech-support  Not-in-family               White    Male
# 53   Exec-managerial  Not-in-family               White  Female
# 63             Sales        Husband  Asian-Pac-Islander    Male
#
#     hours_per_week income           state Results         Model
# 1               18  <=50K        Maryland   <=50K  RandomForest
# 4               40  <=50K         Florida   <=50K  RandomForest
# 13              55   >50K   New Hampshire    >50K  RandomForest
# 16              76   >50K         Wyoming   <=50K  RandomForest
# 22              25  <=50K        New York   <=50K  RandomForest
# 26              32  <=50K        Colorado   <=50K  RandomForest
# 27              40  <=50K         Montana   <=50K  RandomForest
# 28              50   >50K        Colorado   <=50K  RandomForest
# 30              40   >50K        New York   <=50K  RandomForest
# 36              48   >50K            Utah   <=50K  RandomForest
# 37              50   >50K         Arizona    >50K  RandomForest
# 38              60   >50K       Tennessee    >50K  RandomForest
# 40              50   >50K            Utah    >50K  RandomForest
# 41              40   >50K         Indiana   <=50K  RandomForest
# 42              40   >50K          Kansas   <=50K  RandomForest
# 45              70   >50K        Maryland   <=50K  RandomForest
# 51              72   >50K       Louisiana   <=50K  RandomForest
# 52              39   >50K        Illinois   <=50K  RandomForest
# 53              40   >50K  South Carolina   <=50K  RandomForest
# 63              40   >50K      New Mexico    >50K  RandomForest

# %%
# Export
census_copy_df.to_csv('../Data/RandomForest.csv', index_label='index')
