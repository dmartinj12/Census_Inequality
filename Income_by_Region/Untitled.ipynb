# %%
import pandas as pd

# %%
df = pd.read_csv("Race_n_Region_cleaned.csv")
df.head()
# Out:
#                                 Label (Grouping) Alabama  Alaska Arizona  \
# 0                               Total population  28,934  37,094  32,340
# 1                                          White  32,912  44,491  35,496
# 2                      Black or African American  20,378  34,370  25,068
# 3              American Indian and Alaska Native  25,771  20,683  15,878
# 4                                          Asian  35,055  28,797  40,233
#
#   Arkansas California Colorado Connecticut Delaware District of Columbia  ...  \
# 0   27,724     38,576   39,545      45,668   36,574               58,659  ...
# 1   30,301     44,180   42,172      51,357   40,363               91,579  ...
# 2   19,026     31,057   27,950      27,820   27,595               31,672  ...
# 3   21,373     26,164   25,334      25,062   29,250               29,272  ...
# 4   35,423     45,111   38,986      49,368   44,940               72,605  ...
#
# ...

# %%
df_numeric = df.drop(columns=["Label (Grouping)"])  # Exclude the string column
df["United_States(Total)"] = df_numeric.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 df_numeric = df.drop(columns=["Label (Grouping)"])  # Exclude the string column
# ----> 2 df["United_States(Total)"] = df_numeric.sum(axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11670, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11661 @doc(make_doc("sum", ndim=2))
#   11662 def sum(
#   11663     self,
#    (...)
#   11668     **kwargs,
#   11669 ):
# > 11670     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671     return result.__finalize__(self, method="sum")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
# ...

# %%
df.head()
# Out:
#                                 Label (Grouping) Alabama  Alaska Arizona  \
# 0                               Total population  28,934  37,094  32,340
# 1                                          White  32,912  44,491  35,496
# 2                      Black or African American  20,378  34,370  25,068
# 3              American Indian and Alaska Native  25,771  20,683  15,878
# 4                                          Asian  35,055  28,797  40,233
#
#   Arkansas California Colorado Connecticut Delaware District of Columbia  ...  \
# 0   27,724     38,576   39,545      45,668   36,574               58,659  ...
# 1   30,301     44,180   42,172      51,357   40,363               91,579  ...
# 2   19,026     31,057   27,950      27,820   27,595               31,672  ...
# 3   21,373     26,164   25,334      25,062   29,250               29,272  ...
# 4   35,423     45,111   38,986      49,368   44,940               72,605  ...
#
# ...
